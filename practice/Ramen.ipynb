# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('../datasets/ramen-ratings.csv')
df
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country Stars  \
# 0                             T's Restaurant Tantanmen    Cup     Japan  3.75
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan     1
# 2                         Cup Noodles Chicken Vegetable   Cup       USA  2.25
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan  2.75
# 4                                       Singapore Curry  Pack     India  3.75
# ...                                                 ...   ...       ...   ...
# ...

# %%
df.shape
# Out:
# (2580, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2580 non-null   int64
#  1   Brand     2580 non-null   object
#  2   Variety   2580 non-null   object
#  3   Style     2578 non-null   object
#  4   Country   2580 non-null   object
#  5   Stars     2580 non-null   object
#  6   Top Ten   41 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 141.2+ KB

# %%
df.isnull().sum()
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          2
# Country        0
# Stars          0
# Top Ten     2539
# dtype: int64

# %%
df['Top Ten'].unique()
# Out:
# array([nan, '2016 #10', '2016 #1', '2016 #8', '2016 #5', '2016 #9',
#        '2016 #7', '2015 #10', '2015 #7', '2015 #4', '2015 #9', '2015 #6',
#        '2015 #1', '2013 #10', '2015 #8', '2014 #7', '2014 #4', '2014 #9',
#        '2014 #10', '2014 #8', '2014 #5', '2014 #6', '2014 #1', '2013 #1',
#        '2013 #2', '2013 #4', '\n', '2013 #9', '2013 #3', '2012 #10',
#        '2012 #7', '2012 #5', '2012 #3', '2012 #6', '2012 #9', '2012 #1',
#        '2012 #2', '2013 #6', '2012 #4'], dtype=object)

# %%
# df[df['Top Ten'].notnull()]

# %%
df[df['Top Ten'] == '\n']
# Out:
#       Review #     Brand                                     Variety Style  \
# 1670       910     Paldo                                Namja Ramyun  Bowl
# 1846       734   Indomie  Mi Goreng Rasa Ayam Panggang Jumbo (Local)  Pack
# 2248       332  Nongshim                   Champong Oriental Noodles   Cup
# 2535        45   Indomie                              Mi Goreng Sate  Pack
#
#           Country Stars Top Ten
# 1670  South Korea  4.25      \n
# 1846    Indonesia     5      \n
# 2248  South Korea  3.75      \n
# 2535    Indonesia     5      \n

# %%
# df['Top Ten'] = df['Top Ten'].replace(['\n'], np.
# Out:
#   Input In [7]
#     df['Top Ten'] = df['Top Ten'].replace(['\n'], np.
#                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
# plotting data on map
fig = px.choropleth(df,  locations='Country', color='Stars',
#                            color_continuous_scale="Review #",
                           range_color=(0, 12),
#                            scope="usa",
#                            labels={'unemp':'unemployment rate'}
                          )
# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="afa2cb16-5012-481d-ace6-2b6b51afc176" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afa2cb16-5012-481d-ace6-2b6b51afc176")) {                    Plotly.newPlot(                        "afa2cb16-5012-481d-ace6-2b6b51afc176",                        [{"colorscale":[[0.0,"#636efa"],[1.0,"#636efa"]],"geo":"geo","hovertemplate":"Stars=3.75<br>Country=%{location}<extra></extra>","locations":["Japan","India","Japan","India","Japan","Hong Kong","South Korea","Singapore","Germany","Germany","Germany","Germany","Hungary","Germany","South Korea","USA","China","Singapore","Japan","USA","South Korea","China","Indonesia","USA","USA","USA","India","Hong Kong","Hong Kong","South Korea","South Korea","USA","Hong Kong","Hong
# ...

# %%
df['Country'].value_counts()
# Out:
# Japan            352
# USA              323
# South Korea      309
# Taiwan           224
# Thailand         191
# China            169
# Malaysia         156
# Hong Kong        137
# Indonesia        126
# Singapore        109
# Vietnam          108
# UK                69
# Philippines       47
# Canada            41
# India             31
# Germany           27
# Mexico            25
# Australia         22
# Netherlands       15
# Myanmar           14
# Nepal             14
# Pakistan           9
# Hungary            9
# Bangladesh         7
# Colombia           6
# Brazil             5
# Cambodia           5
# Fiji               4
# Holland            4
# Poland             4
# Finland            3
# Sarawak            3
# Sweden             3
# Dubai              3
# Ghana              2
# Estonia            2
# Nigeria            1
# United States      1
# Name: Country, dtype: int64

# %%
# plot bar graph
# df[df.groupby(['Stars']).groups]
bar = px.bar(df, x='Country', y='Stars')
bar.show()
# Out:
# <div>                            <div id="e53990ad-58aa-40c0-8d7c-ebbb545d122b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e53990ad-58aa-40c0-8d7c-ebbb545d122b")) {                    Plotly.newPlot(                        "e53990ad-58aa-40c0-8d7c-ebbb545d122b",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Stars=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Japan","Taiwan","USA","Taiwan","India","South Korea","Japan","Japan","Japan","Singapore","Thailand","USA","South Korea","Japan","Hong Kong","Singapore","India","USA","Vietnam","South Korea","Hong Kong","USA","Singapore","
# ...
