# %% [markdown]
# ##### need to work on some point
# #### 1. after importing dataset identify and remove column which is not usefull. some column are (landmarks,desc)
# #### 2. drop all duplicates rows from dataset
# #### 3.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../datasets/mumbai.csv')
df.head(10)
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
# 5  13000000.0  Bhandup, Mumbai, Bhandup, Mumbai - Central Lin...   630.0
# 6  20700000.0  Siddharth Nagar, Goregaon West, Mumbai, Gorega...  1188.0
# 7  22900000.0  Goregaon West, Mumbai, Best Nagar - Goregaon W...   968.0
# 8  17000000.0  Wadala East, Mumbai, Wadala, Mumbai - Harbour ...   820.0
# 9  81000000.0  Worli, Mumbai, Worli, Mumbai - South Mumbai, M...  3260.0
#
#     latitude  longitude  Bedrooms  Bathrooms  Balcony              Status  \
# 0  19.032800  72.896357       2.0        2.0      NaN  Under Construction
# ...

# %%
df.shape
# Out:
# (6255, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6255 entries, 0 to 6254
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             6255 non-null   float64
#  1   Address           6255 non-null   object
#  2   area              6255 non-null   float64
#  3   latitude          6255 non-null   float64
#  4   longitude         6255 non-null   float64
#  5   Bedrooms          6255 non-null   float64
#  6   Bathrooms         6255 non-null   float64
#  7   Balcony           2376 non-null   float64
#  8   Status            5774 non-null   object
#  9   neworold          6255 non-null   object
#  10  parking           2129 non-null   float64
#  11  Furnished_status  3600 non-null   object
#  12  Lift              1678 non-null   float64
#  13  Landmarks         2617 non-null   object
#  14  type_of_building  6255 non-null   object
#  15  desc              6255 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony             3879
# Status               481
# neworold               0
# parking             4126
# Furnished_status    2655
# Lift                4577
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
#working for coulmn balcony 
df.Balcony.unique()
#now here in balcony many rows are nan, show replaing it with 0
# Out:
# array([nan,  2.,  3.,  1.,  4.,  5.,  6.,  7.,  8.])

# %%
df['Balcony'] = df['Balcony'].fillna(0)
df.Balcony.unique()
# Out:
# array([0., 2., 3., 1., 4., 5., 6., 7., 8.])

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony                0
# Status               481
# neworold               0
# parking             4126
# Furnished_status    2655
# Lift                4577
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
# column status
df['Status'].unique()
# Out:
# array(['Under Construction', 'Ready to Move', nan], dtype=object)

# %%
Statusnan = df[df['Status'].isna()]
Statusnan.shape
# Out:
# (481, 17)

# %% [markdown]
# ##### here for column status to replace nan value, for  that idea is
# ##### 1. check column "neworold" if this column has resale than status column nan values should be replaced with 'Ready to Move' string

# %%
Statusnan
# Out:
#            price                                            Address    area  \
# 4     13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
# 5     13000000.0  Bhandup, Mumbai, Bhandup, Mumbai - Central Lin...   630.0
# 6     20700000.0  Siddharth Nagar, Goregaon West, Mumbai, Gorega...  1188.0
# 7     22900000.0  Goregaon West, Mumbai, Best Nagar - Goregaon W...   968.0
# 8     17000000.0  Wadala East, Mumbai, Wadala, Mumbai - Harbour ...   820.0
# ...          ...                                                ...     ...
# 6158   4500000.0     Kala Ghoda, Mumbai - South Mumbai, Maharashtra   900.0
# 6209  22500000.0         Colaba, Mumbai - South Mumbai, Maharashtra   800.0
# 6213   6000000.0  Vasai west, Vasai West, Mumbai - Mira Road and...   600.0
# 6228  16500000.0  Lower Parel East, Mumbai - South Mumbai, Mahar...   700.0
# 6249  11500000.0  bldg no-137, axiom aven, near ganesh mandir, p...   550.0
#
# ...

# %% [markdown]
# ##### replacing nan value with neworold column based on resale string

# %%
StatusWNeworold = df[(df['Status'].isna()) & (df['neworold'] == 'Resale')]
StatusWNeworold.shape
# Out:
# (255, 17)

# %%
def handle_status_forresale(value):
    if value in StatusWNeworold:
        print(value)
#         return 'others'
    else:
        print(value)
#         return value
       
    
    
df['Status'] = df['Status'].apply(handle_status_forresale)
df['Status'].value_counts()
# Out:
# Under Construction
# Under Construction
# Under Construction
# Ready to Move
# nan
# nan
# nan
# nan
# nan
# Ready to Move
# nan
# nan
# Ready to Move
# nan
# Ready to Move
# nan
# Ready to Move
# Ready to Move
# Ready to Move
# Ready to Move
# Ready to Move
# nan
# Ready to Move
# nan
# Ready to Move
# Ready to Move
# Ready to Move
# Ready to Move
# Ready to Move
# Ready to Move
# Ready to Move
# Ready to Move
# nan
# Ready to Move
# Ready to Move
# Ready to Move
# Ready to Move
# Ready to Move
# nan
# Ready to Move
# Ready to Move
# nan
# Ready to Move
# Ready to Move
# nan
# nan
# Ready to Move
# Ready to Move
# nan
# Ready to Move
# Ready to Move
# nan
# nan
# nan
# Ready to Move
# nan
# nan
# Ready to Move
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Ready to Move
# nan
# Ready to Move
# Ready to Move
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Ready to Move
# nan
# nan
# ...

# %%
df[(df['Status'].isna()) & (df['neworold'] == 'Resale')]
# Out:
# C:\Users\Ajay\AppData\Local\Temp\ipykernel_1012\2018262509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[(df['Status'].isna()) & (df['neworold'] == 'Resale')].fillna('Ready to Move', inplace=True)

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony                0
# Status               481
# neworold               0
# parking                0
# Furnished_status       0
# Lift                   0
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %%
df[df['Status'].isna()].shape

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony                0
# Status               481
# neworold               0
# parking             4126
# Furnished_status    2655
# Lift                4577
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %% [markdown]
# #### clening parking column

# %%
df['parking'].unique()
# Out:
# array([ nan,   1.,   3.,   2.,  11.,   4.,  20.,  30.,   5.,   8., 603.,
#        205., 401.,  75.,   7., 185., 150.,  10.,   6., 202.,  14.,  12.,
#         55., 163., 104., 702.,   9.,  21.,  40., 105., 101., 418.,  60.,
#        125.,  65.,  18.,  15., 601.,  22.,  24.,  26., 801., 102., 302.,
#         16.])

# %% [markdown]
# ##### in this coulumn we have large no. of rows having nan values. Instead of droping  rows. Replacing nan value with 0

# %%
df['parking'] = df['parking'].fillna(0)
df['parking'].unique()
# Out:
# array([  0.,   1.,   3.,   2.,  11.,   4.,  20.,  30.,   5.,   8., 603.,
#        205., 401.,  75.,   7., 185., 150.,  10.,   6., 202.,  14.,  12.,
#         55., 163., 104., 702.,   9.,  21.,  40., 105., 101., 418.,  60.,
#        125.,  65.,  18.,  15., 601.,  22.,  24.,  26., 801., 102., 302.,
#         16.])

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony                0
# Status               481
# neworold               0
# parking                0
# Furnished_status    2655
# Lift                4577
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %% [markdown]
# ##### Check Furnished_status

# %%
df['Furnished_status'].unique()
# Out:
# array([nan, 'Unfurnished', 'Semi-Furnished', 'Furnished'], dtype=object)

# %% [markdown]
# ##### so, what here we can do is try to replace nan with 'Unfurnished' string and later check its outcome and acording to that we can
# ##### if needed change nan value with some other string

# %%
df['Furnished_status'] =df['Furnished_status'].fillna('Unfurnished')

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony                0
# Status               481
# neworold               0
# parking                0
# Furnished_status       0
# Lift                4577
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %% [markdown]
# ##### column lift

# %%
df['Lift'].unique()
# Out:
# array([ 2.,  3.,  5.,  6.,  4., nan,  8.,  1.,  7.,  0., 10.,  9.])

# %%
df['Lift'].value_counts()
# Out:
# 2.0     758
# 1.0     327
# 3.0     220
# 4.0     174
# 0.0      55
# 5.0      51
# 6.0      49
# 7.0      18
# 8.0      11
# 10.0     11
# 9.0       4
# Name: Lift, dtype: int64

# %%
df['Lift'] =df['Lift'].fillna(0.0)

# %%
df.isnull().sum()
# Out:
# price                  0
# Address                0
# area                   0
# latitude               0
# longitude              0
# Bedrooms               0
# Bathrooms              0
# Balcony                0
# Status               481
# neworold               0
# parking                0
# Furnished_status       0
# Lift                   0
# Landmarks           3638
# type_of_building       0
# desc                   0
# Price_sqft             0
# dtype: int64

# %% [markdown]
# ##### landmarks column

# %%
df['Landmarks'].unique()
# Out:
# array([nan, 'Laxmi Callista', 'near uper govind nagar', ...,
#        'Jyoti stationery is below the building, you can visit site to enquire',
#        'pant nagar, near ganesh mandir',
#        'Lokhandwala Complex, Andheri West'], dtype=object)
